# %% [markdown]
# # A quick unemployment rate graphic
# *June 10, 2022*

# %% [markdown]
# New labour force survey data today, so we'll chart it quickly for stories on CBCNews.ca.
#
# Import a few libraries we'll need to use.

# %%
import pandas as pd
from zipfile import ZipFile
from io import BytesIO
import requests
import datawrappergraphics

# %% [markdown]
# Load in the data. StatsCan provides these comprehensive files in zip format, so we need a few extra lines to parse the data.

# %%
r = requests.get("https://www150.statcan.gc.ca/n1/tbl/csv/14100287-eng.zip")
files = ZipFile(BytesIO(r.content))
file = files.open(files.namelist()[0])
raw = pd.read_csv(file, encoding="utf-8")

raw.head(5)
# Out:
# C:\Users\dexmc\AppData\Local\Temp\ipykernel_60192\3438196510.py:4: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv(file, encoding="utf-8")
#   REF_DATE     GEO           DGUID Labour force characteristics         Sex  \
# 0  1976-01  Canada  2016A000011124                   Population  Both sexes
# 1  1976-01  Canada  2016A000011124                   Population  Both sexes
# 2  1976-01  Canada  2016A000011124                   Population  Both sexes
# 3  1976-01  Canada  2016A000011124                   Population  Both sexes
# 4  1976-01  Canada  2016A000011124                   Population  Both sexes
#
#            Age group Statistics            Data type      UOM  UOM_ID  \
# 0  15 years and over   Estimate  Seasonally adjusted  Persons     249
# 1  15 years and over   Estimate           Unadjusted  Persons     249
# 2     15 to 64 years   Estimate  Seasonally adjusted  Persons     249
# 3     15 to 64 years   Estimate           Unadjusted  Persons     249
# 4     15 to 24 years   Estimate  Seasonally adjusted  Persons     249
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR   COORDINATE    VALUE STATUS  SYMBOL  \
# 0     thousands          3   v2062809  1.1.1.1.1.1  16852.4    NaN     NaN
# 1     thousands          3   v2064888  1.1.1.1.1.2  16852.4    NaN     NaN
# 2     thousands          3  v21580997  1.1.1.8.1.1  15015.9    NaN     NaN
# 3     thousands          3  v21580998  1.1.1.8.1.2  15015.9    NaN     NaN
# 4     thousands          3   v2062836  1.1.1.2.1.1   4509.9    NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         1
# 1         NaN         1
# 2         NaN         1
# 3         NaN         1
# 4         NaN         1

# %% [markdown]
# Now we filter for the values we want to show.

# %%
data = (raw.loc[
    (raw["GEO"] == "Canada") &
    (raw["Labour force characteristics"] == "Unemployment rate") &
    (raw["Sex"] == "Both sexes") & (raw["Age group"] == '15 years and over') &
    (raw["Statistics"] == "Estimate") &
    (raw["Data type"] == "Seasonally adjusted"),
    :]
    )

data.head(5)
# Out:
#       REF_DATE     GEO           DGUID Labour force characteristics  \
# 636    1976-01  Canada  2016A000011124            Unemployment rate
# 9627   1976-02  Canada  2016A000011124            Unemployment rate
# 18618  1976-03  Canada  2016A000011124            Unemployment rate
# 27609  1976-04  Canada  2016A000011124            Unemployment rate
# 36600  1976-05  Canada  2016A000011124            Unemployment rate
#
#               Sex          Age group Statistics            Data type  \
# 636    Both sexes  15 years and over   Estimate  Seasonally adjusted
# 9627   Both sexes  15 years and over   Estimate  Seasonally adjusted
# 18618  Both sexes  15 years and over   Estimate  Seasonally adjusted
# 27609  Both sexes  15 years and over   Estimate  Seasonally adjusted
# 36600  Both sexes  15 years and over   Estimate  Seasonally adjusted
#
#               UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR   COORDINATE  \
# 636    Percentage     242        units           0  v2062815  1.7.1.1.1.1
# 9627   Percentage     242        units           0  v2062815  1.7.1.1.1.1
# 18618  Percentage     242        units           0  v2062815  1.7.1.1.1.1
# 27609  Percentage     242        units           0  v2062815  1.7.1.1.1.1
# 36600  Percentage     242        units           0  v2062815  1.7.1.1.1.1
#
#        VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 636      7.1    NaN     NaN         NaN         1
# 9627     7.0    NaN     NaN         NaN         1
# 18618    6.7    NaN     NaN         NaN         1
# 27609    6.8    NaN     NaN         NaN         1
# 36600    6.9    NaN     NaN         NaN         1

# %% [markdown]
# Now we chart it. I sent the data to datawrapper's app, then styled it over there. I'm showing it here using a module I created for that purpose.

# %%
filtered = data[["REF_DATE", "VALUE"]]

chart = datawrappergraphics.Chart("JF8UC").data(filtered).head(f"Unemployment in Canada").publish().show()

chart
# Out:
# INFO:root:SUCCESS: Data added to chart.
# INFO:root:SUCCESS: Chart head added.
# INFO:root:SUCCESS: Chart published!
# c:\Users\dexmc\anaconda3\envs\geo\lib\site-packages\IPython\core\display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe title="Unemployment rate in Canada" aria-label="Interactive line chart" id="datawrapper-chart-JF8UC" src="https://datawrapper.dwcdn.net/JF8UC/4/" scrolling="no" frameborder="0" style="border: none;" width="720" height="500"></iframe>

# %% [markdown]
# Fin.
#
# \-30\-
