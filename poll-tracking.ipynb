# %%
import pandas as pd
import requests
import json

# %%
test = pd.DataFrame({"Polling": ["John Doe", "Jane Green"], "Value": [39,20]})
test2 = pd.DataFrame({"Polling": ["A person", "Another person"], "Value": [42,100]})

headers = {
    "Accept": "*/*", 
    "Authorization": "Bearer u6YodcMqfBxZb2RkvlYoGq8xaXPmjQlVGJE4nNazAXpOEQ7BQ1iAxjReRlk3A2gF",
    "Content-Type": "application/json"
}
response = requests.request("POST", "https://api.datawrapper.de/v3/charts/6LfI8/copy", headers=headers)

chart_id = response.json()["id"]
payload = test2.to_csv()

print(payload)

response2 = requests.request("PUT", f'https://api.datawrapper.de/v3/charts/{chart_id}/data', json=payload, headers=headers)

display(response.text)
# Out:
# ,Polling,Value
# 0,A person,42
# 1,Another person,100
# ...
