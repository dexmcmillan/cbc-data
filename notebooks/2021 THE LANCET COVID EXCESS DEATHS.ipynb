# %% [markdown]
# # The Lancet excess death study data

# %% [markdown]
# A look at excess mortality around the world using [data published on March 10, 2022 in The Lancet](https://www.thelancet.com/journals/lancet/article/PIIS0140-6736(21)02796-3/fulltext#seccestitle150).
#
# First we import pandas, which we'll use for the analysis.

# %%
import pandas as pd

# %% [markdown]
# Then we download the data and put it into the "raw" folder of the repository.

# %%
raw = pd.read_csv('../raw/RAW 2021 THE LANCET EXCESS DEATHS.csv', encoding="latin-1", thousands=',')

# %% [markdown]
# ## Summary of all countries

# %% [markdown]
# Let's gather all the countries into one table, with separate columns for each indicator.

# %%
# Level 3 is the one used for country-level data.
countries_only = raw[raw["level"] == 3]
pivot = pd.pivot(countries_only, index="location_name", columns="measure_name", values="mean_value")

display(pivot.head(5))
# Out:
# measure_name   covid_death_rate  excess_death_rate  excess_deaths  \
# location_name
# Afghanistan                 8.1              211.9       192000.0
# Albania                    64.4              346.5        17300.0
# Algeria                     7.5               65.1        54400.0
# Andorra                    87.6              205.5          328.0
# Angola                      3.0              107.3        64000.0
#
# measure_name   ratio_excess_over_covid  reported_covid_deaths
# location_name
# Afghanistan                      26.06                 7360.0
# Albania                           5.38                 3220.0
# Algeria                           8.67                 6280.0
# Andorra                           2.35                  140.0
# Angola                           36.17                 1770.0

# %% [markdown]
# ## Canada - province level data

# %% [markdown]
# We have province-level data in this study! Let's take a look.

# %%
# A look at the data shows that Canada's country ID is 101.
canada = raw[raw["parent_id"] == 101]
canada_pivot = (pd.pivot(canada, index="location_name", columns="measure_name", values="mean_value")
                .sort_values("excess_death_rate", ascending=False))

display(canada_pivot)
# Out:
# measure_name               covid_death_rate  excess_death_rate  excess_deaths  \
# location_name
# Manitoba                               54.5               95.8         2450.0
# Quebec                                 73.0               77.0        12400.0
# Saskatchewan                           43.6               75.8         1660.0
# Alberta                                40.3               67.7         5560.0
# Ontario                                35.3               53.9        15600.0
# British Columbia                       24.2               52.5         5260.0
# Yukon                                  19.7               42.4           32.0
# Northwest Territories                  14.4               38.1           32.0
# Nunavut                                 8.3               27.7           13.0
# New Brunswick                          11.1               27.0          391.0
# Nova Scotia                             6.1               18.0          327.0
# Newfoundland and Labrador               2.0               11.0          106.0
#
# measure_name               ratio_excess_over_covid  reported_covid_deaths
# location_name
# Manitoba                                      1.76                 1390.0
# Quebec                                        1.05                11700.0
# Saskatchewan                                  1.74                  955.0
# Alberta                                       1.68                 3310.0
# Ontario                                       1.53                10200.0
# British Columbia                              2.17                 2420.0
# Yukon                                         2.15                   15.0
# Northwest Territories                         2.64                   12.0
# Nunavut                                       3.35                    4.0
# New Brunswick                                 2.44                  160.0
# Nova Scotia                                   2.95                  111.0
# Newfoundland and Labrador                     5.59                   19.0
