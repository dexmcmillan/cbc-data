# %%
import pandas as pd

# %% [markdown]
# ## CMA Population Changes from 2016 to 2021

# %%
raw = pd.read_csv("../raw/RAW 2021 STATSCAN CENSUS 1.csv", encoding = 'unicode_escape', engine ='python')

# %%
population_raw = raw[raw["CHARACTERISTIC_NAME"].isin(["Population percentage change, 2016 to 2021"])]

# %%
population_pivot = pd.pivot(population_raw, index=["ALT_GEO_CODE", "GEO_NAME"], columns="CHARACTERISTIC_NAME", values="C1_COUNT_TOTAL").reset_index().set_index("ALT_GEO_CODE")
display(population_pivot)

population_pivot.to_csv("../exports/populations2021.csv")
# Out:
# CHARACTERISTIC_NAME                                           GEO_NAME  \
# ALT_GEO_CODE
# 1                                                           St. John's
# 10                                                 Grand Falls-Windsor
# 11                                                              Gander
# 15                                                        Corner Brook
# 105                                                      Charlottetown
# ...                                                                ...
# 24505                Ottawa - Gatineau (partie du Québec / Quebec p...
# 35502                Hawkesbury (Ontario part / partie de l'Ontario...
# 35505                Ottawa - Gatineau (Ontario part / partie de l'...
# 47840                Lloydminster (Saskatchewan part / partie de la...
# 48840                Lloydminster (Alberta part / partie de l'Alber...
#
# CHARACTERISTIC_NAME  Population percentage change, 2016 to 2021
# ALT_GEO_CODE
# 1                                                           2.0
# 10                                                         -2.2
# 11                                                          1.4
# 15                                                         -3.9
# 105                                                         9.8
# ...                                                         ...
# 24505                                                       6.3
# 35502                                                      -0.7
# 35505                                                       9.2
# 47840                                                      -1.9
# 48840                                                       0.5
#
# [160 rows x 2 columns]

# %%
cmas = population_raw[["ALT_GEO_CODE", "GEO_NAME"]].drop_duplicates(subset="ALT_GEO_CODE")
code = cmas["ALT_GEO_CODE"].astype(str).str[-3:].astype(int)
cmas["ALT_GEO_CODE"] = code


display(cmas)
cmas.to_csv("../export/scmas_list.csv")

# %% [markdown]
# ## Census subdivisions - Change from 2016 to 2021

# %%
raw_csd = pd.read_csv("raw/RAW 2021 STATSCAN CENSUS CSD.csv", encoding = 'unicode_escape', engine ='python')

display(raw_csd)
# Out:
#        CENSUS_YEAR             DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 0             2021    2021A000011124             1             Country
# 1             2021    2021A000011124             1             Country
# 2             2021    2021A000011124             1             Country
# 3             2021    2021A000011124             1             Country
# 4             2021    2021A000011124             1             Country
# ...            ...               ...           ...                 ...
# 38271         2021  2021A00056208098       6208098  Census subdivision
# 38272         2021  2021A00056208098       6208098  Census subdivision
# 38273         2021  2021A00056208098       6208098  Census subdivision
# 38274         2021  2021A00056208098       6208098  Census subdivision
# 38275         2021  2021A00056208098       6208098  Census subdivision
#
#                                                 GEO_NAME  DATA_QUALITY_FLAG  \
# 0                                                 Canada              20000
# 1                                                 Canada              20000
# 2                                                 Canada              20000
# 3                                                 Canada              20000
# 4                                                 Canada              20000
# ...                                                  ...                ...
# 38271  Kitikmeot, Unorganized, Unorganized / Non orga...                  0
# 38272  Kitikmeot, Unorganized, Unorganized / Non orga...                  0
# 38273  Kitikmeot, Unorganized, Unorganized / Non orga...                  0
# 38274  Kitikmeot, Unorganized, Unorganized / Non orga...                  0
# 38275  Kitikmeot, Unorganized, Unorganized / Non orga...                  0
#
#        CHARACTERISTIC_ID                            CHARACTERISTIC_NAME  \
# 0                      1                               Population, 2021
# 1                      2                               Population, 2016
# 2                      3     Population percentage change, 2016 to 2021
# 3                      4                        Total private dwellings
# 4                      5  Private dwellings occupied by usual residents
# ...                  ...                                            ...
# 38271                  3     Population percentage change, 2016 to 2021
# 38272                  4                        Total private dwellings
# 38273                  5  Private dwellings occupied by usual residents
# 38274                  6        Population density per square kilometre
# 38275                  7                 Land area in square kilometres
#
#        CHARACTERISTIC_NOTE  C1_COUNT_TOTAL SYMBOL
# 0                      1.0     36991981.00    NaN
# 1                      1.0     35151728.00    NaN
# 2                      NaN            5.20    NaN
# 3                      2.0     16284235.00    NaN
# 4                      3.0     14978941.00    NaN
# ...                    ...             ...    ...
# 38271                  NaN             NaN    ...
# 38272                  2.0            0.00    NaN
# 38273                  3.0            0.00    NaN
# 38274                  NaN            0.00    NaN
# 38275                  NaN       431190.46    NaN
#
# [38276 rows x 11 columns]

# %%
csd = raw_csd[raw_csd["GEO_LEVEL"] == "Census subdivision"]
csd = csd[csd["CHARACTERISTIC_NAME"].isin(["Population percentage change, 2016 to 2021", "Population, 2021"])]

csd_pivot = pd.pivot(csd, index=["DGUID", "GEO_NAME", "ALT_GEO_CODE"], columns="CHARACTERISTIC_NAME", values="C1_COUNT_TOTAL").reset_index()

display(csd_pivot)
csd_pivot.to_csv("../../../exports/cts_formapping.csv")
# Out:
# CHARACTERISTIC_NAME             DGUID  \
# 0                    2021A00051001101
# 1                    2021A00051001105
# 2                    2021A00051001113
# 3                    2021A00051001120
# 4                    2021A00051001124
# ...                               ...
# 5156                 2021A00056208068
# 5157                 2021A00056208073
# 5158                 2021A00056208081
# 5159                 2021A00056208087
# 5160                 2021A00056208098
#
# CHARACTERISTIC_NAME                                           GEO_NAME  \
# 0                    Division No.  1, Subd. V, Subdivision of unorg...
# 1                                        Portugal Cove South, Town (T)
# 2                                                  Trepassey, Town (T)
# 3                                                St. Shott's, Town (T)
# 4                    Division No.  1, Subd. U, Subdivision of unorg...
# ...                                                                ...
# 5156                                     Umingmaktok, Settlement (SET)
# 5157                                       Cambridge Bay, Hamlet (HAM)
# 5158                                          Gjoa Haven, Hamlet (HAM)
# 5159                                            Taloyoak, Hamlet (HAM)
# 5160                 Kitikmeot, Unorganized, Unorganized / Non orga...
#
# CHARACTERISTIC_NAME  ALT_GEO_CODE  Population percentage change, 2016 to 2021  \
# 0                         1001101                                        52.8
# 1                         1001105                                       -42.7
# 2                         1001113                                       -15.8
# 3                         1001120                                       -16.7
# 4                         1001124                                       -15.5
# ...                           ...                                         ...
# 5156                      6208068                                         NaN
# 5157                      6208073                                        -0.3
# 5158                      6208081                                         1.9
# 5159                      6208087                                        -9.2
# 5160                      6208098                                         NaN
#
# CHARACTERISTIC_NAME  Population, 2021
# 0                                55.0
# 1                                86.0
# 2                               405.0
# 3                                55.0
# 4                              1373.0
# ...                               ...
# 5156                              0.0
# 5157                           1760.0
# 5158                           1349.0
# 5159                            934.0
# 5160                              0.0
#
# [5161 rows x 5 columns]

# %%
csd_pivot = pd.pivot(csd, index=["DGUID", "GEO_NAME"], columns="CHARACTERISTIC_NAME", values="C1_COUNT_TOTAL").reset_index()
name = csd_pivot["GEO_NAME"].str.split(", ", expand=True)[0]
csd_pivot["TYPE"] = csd_pivot["GEO_NAME"].str.split(", ", expand=True)[1]
csd_pivot["GEO_NAME"] = name

display(csd_pivot)
csd_pivot.to_csv("exports/census2021.csv")
csd_pivot.to_clipboard()
# Out:
# CHARACTERISTIC_NAME             DGUID             GEO_NAME  \
# 0                    2021A00051001101      Division No.  1
# 1                    2021A00051001105  Portugal Cove South
# 2                    2021A00051001113            Trepassey
# 3                    2021A00051001120          St. Shott's
# 4                    2021A00051001124      Division No.  1
# ...                               ...                  ...
# 5156                 2021A00056208068          Umingmaktok
# 5157                 2021A00056208073        Cambridge Bay
# 5158                 2021A00056208081           Gjoa Haven
# 5159                 2021A00056208087             Taloyoak
# 5160                 2021A00056208098            Kitikmeot
#
# CHARACTERISTIC_NAME  Population percentage change, 2016 to 2021  \
# 0                                                          52.8
# 1                                                         -42.7
# 2                                                         -15.8
# 3                                                         -16.7
# 4                                                         -15.5
# ...                                                         ...
# 5156                                                        NaN
# 5157                                                       -0.3
# 5158                                                        1.9
# 5159                                                       -9.2
# 5160                                                        NaN
#
# CHARACTERISTIC_NAME  Population, 2021              TYPE
# 0                                55.0           Subd. V
# 1                                86.0          Town (T)
# 2                               405.0          Town (T)
# 3                                55.0          Town (T)
# 4                              1373.0           Subd. U
# ...                               ...               ...
# 5156                              0.0  Settlement (SET)
# 5157                           1760.0      Hamlet (HAM)
# 5158                           1349.0      Hamlet (HAM)
# 5159                            934.0      Hamlet (HAM)
# 5160                              0.0       Unorganized
#
# [5161 rows x 5 columns]

# %% [markdown]
# ## Census tracts - Change from 2011 to 2016

# %%
tracts_raw = pd.read_csv("../raw/RAW 2021 STATSCAN CENSUS TRACTS.csv", encoding = 'unicode_escape', engine ='python')
tracts_raw["ALT_GEO_CODE"] = tracts_raw["ALT_GEO_CODE"].astype(float)

# %%
tracts_population = tracts_raw[tracts_raw["CHARACTERISTIC_NAME"] == "Population percentage change, 2016 to 2021"]
tracts_population = tracts_population[tracts_population["GEO_LEVEL"] == 'Census tract']

# %%
tracts_pivot = pd.pivot(tracts_population, columns="CHARACTERISTIC_NAME", index=["DGUID", "GEO_NAME"], values="C1_COUNT_TOTAL").reset_index().set_index("DGUID")

tracts_pivot.to_csv('../exports/censustracts_change.csv')

# %% [markdown]
# ## Census divisions

# %%
raw_csd = pd.read_csv("../raw/RAW 2021 STATSCAN CENSUS CSD.csv", encoding = 'unicode_escape', engine ='python')
sd = raw_csd[raw_csd["GEO_LEVEL"] == "Census division"]
sd = sd[sd["CHARACTERISTIC_NAME"] == "Population percentage change, 2016 to 2021"]

# %%
sd_table = sd[["ALT_GEO_CODE", "GEO_NAME", "C1_COUNT_TOTAL"]].set_index("ALT_GEO_CODE")

sd_list = sd_table.drop_duplicates()
sd_list.to_clipboard()

# %%
sd_clean = sd_table.copy()
sd_clean["GEO_NAME"] = sd_clean["GEO_NAME"].astype(str).str.replace(pat=", Region (REG)", repl="",regex=False)
sd_clean["GEO_NAME"] = sd_clean["GEO_NAME"].astype(str).str.replace(pat=", Regional district (RD)", repl="",regex=False)
sd_clean["GEO_NAME"] = sd_clean["GEO_NAME"].astype(str).str.replace(pat=", District (DIS)", repl="",regex=False)
sd_clean["GEO_NAME"] = sd_clean["GEO_NAME"].astype(str).str.replace(pat=", County (CTY)", repl="",regex=False)
sd_clean["GEO_NAME"] = sd_clean["GEO_NAME"].astype(str).str.split(pat=" / ", expand=True)[0]

sd_clean.to_csv("exports/2021divisions.csv")
# Out:
#                                       GEO_NAME  C1_COUNT_TOTAL
# ALT_GEO_CODE
# 1001          Division No.  1, Census division             0.6
# 1002          Division No.  2, Census division            -4.8
# 1003          Division No.  3, Census division           -10.5
# 1004          Division No.  4, Census division            -5.6
# 1005          Division No.  5, Census division            -3.9
# ...                                        ...             ...
# 6105                                  Region 5           -10.0
# 6106                                  Region 6             3.6
# 6204                               Qikiqtaaluk             1.9
# 6205                                  Kivalliq             6.1
# 6208                                 Kitikmeot            -1.3
#
# [293 rows x 2 columns]
