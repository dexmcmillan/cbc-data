# %% [markdown]
# # Ontario sunshine list 2020

# %%
import pandas as pd
import numpy as np
import json
import urllib
import requests

pd.options.display.float_format = '{:,}'.format

raw = pd.read_csv('raw\sunshine_2020.csv', encoding="latin-1", thousands=',')

raw["Sector"] = raw["Sector"].str.strip()
raw["Name"] = raw["First Name"] + " " + raw["Last Name"]
raw["Salary"] = raw["Salary"].str.replace(pat="$", repl="").str.replace(pat=",", repl="", regex=False).astype(float)
raw["Benefits"] = raw["Benefits"].str.replace(pat="$", repl="").str.replace(pat=",", repl="", regex=False).astype(float)
raw = raw[~raw["Sector"].str.contains("Second")]
raw = raw.sort_values('Salary', ascending=False)

# Binning into brackets
min_value = raw['Salary'].min()
max_value = raw['Salary'].max()

bins = np.linspace(min_value,max_value,5)
for i, number in enumerate(bins, 0):
    bins[i] = round(number, -4)
bins = np.append(bins, 5000000)
labels = []

for i, number in enumerate(bins, 0):
    try:
        label = "$" + str(round(bins[i])) + " - $" + str(round(bins[i+1]))
        label = label
        labels.append(label)
    except:
        print(labels)
    
raw["Earnings Bracket"] = pd.cut(raw['Salary'], bins=bins, labels=labels, include_lowest=True)
# raw["Earnings Bracket"] = raw["Earnings Bracket"].fillna(">" + str(bins[-1]))

display(raw)
# Out:
# C:\Users\dexmc\AppData\Local\Temp/ipykernel_50568/3527401325.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   raw["Salary"] = raw["Salary"].str.replace(pat="$", repl="").str.replace(pat=",", repl="", regex=False).astype(float)
# C:\Users\dexmc\AppData\Local\Temp/ipykernel_50568/3527401325.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   raw["Benefits"] = raw["Benefits"].str.replace(pat="$", repl="").str.replace(pat=",", repl="", regex=False).astype(float)
# ['$100000 - $380000', '$380000 - $660000', '$660000 - $950000', '$950000 - $1230000', '$1230000 - $5000000']
#                                      Sector  Last Name First Name  \
# 126331             Ontario Power Generation   Hartwick    Kenneth
# 128457             Ontario Power Generation    Miniere  Dominique
# 126080             Ontario Power Generation  Granville       Sean
# 128014             Ontario Power Generation   Martelli    Michael
# 65303   Hospitals & Boards of Public Health      Smith      Kevin
# ...                                     ...        ...        ...
# 189456                         Universities    Elrayes      Maged
# 134869        Other Public Sector Employers     Hyslop    Carolyn
# 135149        Other Public Sector Employers       Karn     Denyse
# 137936        Other Public Sector Employers     Rubino   Rosaleen
# 132188        Other Public Sector Employers    Billing      Anita
#
#              Salary  Benefits  \
# 126331  1,228,517.0  7,539.84
# 128457 1,131,767.04  3,922.56
# 126080   901,606.32  2,450.88
# 128014   850,332.27   3,499.2
# 65303     844,992.2 87,502.71
# ...             ...       ...
# 189456    100,000.0       0.0
# 134869    100,000.0       0.0
# 135149    100,000.0    830.52
# 137936    100,000.0       0.0
# 132188    100,000.0     623.9
#
#                                                  Employer  \
# 126331                           Ontario Power Generation
# 128457                           Ontario Power Generation
# 126080                           Ontario Power Generation
# 128014                           Ontario Power Generation
# 65303                           University Health Network
# ...                                                   ...
# 189456                      University Of Western Ontario
# 134869                              Canadian Canoe Museum
# 135149    Toronto Festival Of Arts Culture And Creativity
# 137936  Rosaleen Rubino Physiotherapy Professional Cor...
# 132188                                    Variety Village
#
#                                                 Job Title  Year  \
# 126331              President and Chief Executive Officer  2020
# 128457                                 President, Nuclear  2020
# 126080  Chief Operations Officer and Chief Nuclear Off...  2020
# 128014                             Chief Projects Officer  2020
# 65303               President and Chief Executive Officer  2020
# ...                                                   ...   ...
# 189456                                    Clinical Fellow  2020
# 134869                                 Executive Director  2020
# 135149                               Director, Production  2020
# 137936                                           Director  2020
# 132188                            Chief Financial Officer  2020
#
#                      Name    Earnings Bracket
# 126331   Kenneth Hartwick  $950000 - $1230000
# 128457  Dominique Miniere  $950000 - $1230000
# 126080     Sean Granville   $660000 - $950000
# 128014   Michael Martelli   $660000 - $950000
# 65303         Kevin Smith   $660000 - $950000
# ...                   ...                 ...
# 189456      Maged Elrayes   $100000 - $380000
# 134869     Carolyn Hyslop   $100000 - $380000
# 135149        Denyse Karn   $100000 - $380000
# 137936    Rosaleen Rubino   $100000 - $380000
# 132188      Anita Billing   $100000 - $380000
#
# [205719 rows x 10 columns]

# %%
bracket_counts = pd.pivot_table(raw, index="Earnings Bracket", columns="Sector", aggfunc='count', values="Name")
percent_counts = pd.DataFrame()

for label, col in bracket_counts.items():
    percent_counts[label] = round((bracket_counts[label] / bracket_counts[label].sum()) * 100, 2)

display(percent_counts)
bracket_counts.to_clipboard()
# Out:
#                      Colleges  Crown Agencies  \
# Earnings Bracket
# $100000 - $380000       99.95            99.6
# $380000 - $660000        0.05            0.36
# $660000 - $950000         0.0            0.03
# $950000 - $1230000        0.0             0.0
# $1230000 - $5000000       0.0             0.0
#
#                      Government of Ontario - Judiciary  \
# Earnings Bracket
# $100000 - $380000                                100.0
# $380000 - $660000                                  0.0
# $660000 - $950000                                  0.0
# $950000 - $1230000                                 0.0
# $1230000 - $5000000                                0.0
#
#                      Government of Ontario - Legislative Assembly and Offices  \
# Earnings Bracket
# $100000 - $380000                                                100.0
# $380000 - $660000                                                  0.0
# $660000 - $950000                                                  0.0
# $950000 - $1230000                                                 0.0
# $1230000 - $5000000                                                0.0
#
#                      Government of Ontario - Ministries  \
# Earnings Bracket
# $100000 - $380000                                 99.93
# $380000 - $660000                                  0.07
# $660000 - $950000                                   0.0
# $950000 - $1230000                                  0.0
# $1230000 - $5000000                                 0.0
#
#                      Hospitals & Boards of Public Health  \
# Earnings Bracket
# $100000 - $380000                                  99.57
# $380000 - $660000                                    0.4
# $660000 - $950000                                   0.03
# $950000 - $1230000                                   0.0
# $1230000 - $5000000                                  0.0
#
#                      Municipalities & Services  Ontario Power Generation  \
# Earnings Bracket
# $100000 - $380000                        99.99                     99.71
# $380000 - $660000                         0.01                      0.22
# $660000 - $950000                          0.0                      0.05
# $950000 - $1230000                         0.0                      0.02
# $1230000 - $5000000                        0.0                       0.0
#
#                      Other Public Sector Employers  School Boards  \
# Earnings Bracket
# $100000 - $380000                            99.73          100.0
# $380000 - $660000                             0.27            0.0
# $660000 - $950000                              0.0            0.0
# $950000 - $1230000                             0.0            0.0
# $1230000 - $5000000                            0.0            0.0
#
#                      Universities
# Earnings Bracket
# $100000 - $380000           99.65
# $380000 - $660000            0.35
# $660000 - $950000             0.0
# $950000 - $1230000            0.0
# $1230000 - $5000000           0.0

# %%
categories = raw["Sector"].unique()
sheets = []

for category in categories:
    df = raw[raw["Sector"] == category]
    df["Name/Title"] = "**" + df["Name"] + "**<br>" + df["Job Title"]
    df = df[["Name/Title", "Employer", "Salary", "Benefits"]]
    sheets.append(df)

writer = pd.ExcelWriter('exports/sunshine_list.xlsx')
for i, df in enumerate(sheets, 0):
    df.to_excel(writer, index=False,sheet_name=f'{categories[i]}'[:30])
writer.save()


# display(colleges)
# colleges.to_clipboard()
# Out:
# C:\Users\dexmc\AppData\Local\Temp/ipykernel_50568/3287709192.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name/Title"] = "**" + df["Name"] + "**<br>" + df["Job Title"]

# %%
import json
import urllib
import requests

url = 'https://parseapi.back4app.com/classes/Complete_List_Names'
headers = {
    'X-Parse-Application-Id': 'zsSkPsDYTc2hmphLjjs9hz2Q3EXmnSxUyXnouj1I', # This is the fake app's application id
    'X-Parse-Master-Key': '4LuCXgPPXXO2sU5cXm6WwpwzaKyZpo3Wpj4G4xXK' # This is the fake app's readonly master key
}
data = requests.get(url, headers=headers).json()
print(data)
data2 = json.dumps(data["results"])
names = pd.read_json(data2)
display(names)
# Out:
# {'results': [{'objectId': 'lSxg9sIUv9', 'Name': 'Will', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.261Z', 'updatedAt': '2020-01-23T23:31:09.261Z'}, {'objectId': 'Ypp4vpokki', 'Name': 'James', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.241Z', 'updatedAt': '2020-01-23T23:31:09.241Z'}, {'objectId': 'tZYFQ1Yjyj', 'Name': 'Samuel', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.260Z', 'updatedAt': '2020-01-23T23:31:09.260Z'}, {'objectId': 'LxQmByBQ1y', 'Name': 'John', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.240Z', 'updatedAt': '2020-01-23T23:31:09.240Z'}, {'objectId': '2S3LArF0dw', 'Name': 'George', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.241Z', 'updatedAt': '2020-01-23T23:31:09.241Z'}, {'objectId': 'pJvpTm3AoF', 'Name': 'Sam', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.261Z', 'updatedAt': '2020-01-23T23:31:09.261Z'}, {'objectId': 'E2lkWZ2gD3', 'Name': 'Fred', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.260Z', 'updatedAt': '2020-01-23T23:31:09.260Z'}, {'objectId': 'N6mXAgoM7W', 'Name': 'Richard', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.261Z', 'updatedAt': '2020-01-23T23:31:09.261Z'}, {'objectId': 'eeg5XoXqj5', 'Name': 'William', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.241Z', 'updatedAt': '2020-01-23T23:31:09.241Z'}, {'objectId': 'lEu7T2IVIB', 'Name': 'Bert', 'Gender': 'male', 'createdAt': '2020-01-23T23:31:09.261Z', 'updatedAt': '2020-01-23T23:31:09.261Z'}, {'objectId': 